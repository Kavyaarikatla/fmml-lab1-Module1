# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavyaarikatla/kavyaarikatla-lab-moduies/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-28 07:32:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   142MB/s    in 0.5s
#
# 2023-05-28 07:33:00 (142 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14161  1802.02026v1  Reservoir computing is a bio-inspired computin...    cs
# 16824  1706.03952v2  The ability to accurately perceive whether a s...    cs
# 32237   1305.4076v5  Auto-encoder is a special kind of neural netwo...    cs
# 12230  1710.08846v1  We present a new model-based integrative metho...  stat
# 38005  1803.04965v1  'Sharing of statistical strength' is a phrase ...  stat
# ...             ...                                                ...   ...
# 19568   0907.5033v1  We present two different methods for estimatin...    cs
# 1011   1509.08985v2  We seek to improve deep neural networks by gen...  stat
# 3345   1511.06683v1  Class ambiguity is typical in image classifica...  stat
# 22565  1701.01064v2  Dynamic Mode Decomposition (DMD) has emerged a...  stat
# 20933  1705.06342v1  In this work, we present a methodology that en...    cs
#
#                                                    title  year  \
# 14161  Brain-inspired photonic signal processor for p...  2018
# 16824  Modelling prosodic structure using Artificial ...  2017
# 32237                Contractive De-noising Auto-encoder  2013
# 12230  A Bayesian Method for Joint Clustering of Vect...  2017
# 38005  Coregionalised Locomotion Envelopes - A Qualit...  2018
# ...                                                  ...   ...
# 19568      Online Search Cost Estimation for SAT Solvers  2009
# 1011   Generalizing Pooling Functions in Convolutiona...  2015
# 3345                                Top-k Multiclass SVM  2015
# 22565        Optimal Low-Rank Dynamic Mode Decomposition  2017
# 20933  Identification and Off-Policy Learning of Mult...  2017
#
#                                                 keywords
# 14161  [reservoir, computing, computing, processing, ...
# 16824  [accurately, statement, successful, interactio...
# 32237  [reconstruction, corrupting, reconstructing, m...
# 12230  [integrative, clustering, vectorial, describes...
# 38005  [statistical, processing, predicted, exploitin...
# ...                                                  ...
# 19568  [different, estimating, behaviour, backtrackin...
# 1011   [generalizing, operations, architectures, expl...
# 3345   [ambiguity, classification, difficult, discrim...
# 22565  [decomposition, analyzing, experimental, appro...
# 20933  [methodology, efficient, exploratory, autonomo...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14161    [reservoir, computing, computing, processing, ...
# 16824    [accurately, statement, successful, interactio...
# 32237    [reconstruction, corrupting, reconstructing, m...
# 12230    [integrative, clustering, vectorial, describes...
# 38005    [statistical, processing, predicted, exploitin...
#                                ...
# 23707    [diffusion, framework, geometric, photometric,...
# 40312    [autonomous, themselves, estimation, capabilit...
# 16691    [linguistic, structures, phenomena, universal,...
# 11104    [investigates, quantifying, similarity, specif...
# 22780    [described, applications, sacrifice, predictiv...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8676 words.
# Out of those 4558 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="af9048d5-a5df-4c75-8bc1-491c053488c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af9048d5-a5df-4c75-8bc1-491c053488c7")) {                    Plotly.newPlot(                        "af9048d5-a5df-4c75-8bc1-491c053488c7",                        [{"x":["remarkable","therefore","applications","dependent","benchmark","emulation","computing","significantly","potentially","reservoir","experiments","performance","nonlinear","implementations","computers","introduce","investigations","demonstrate","generation","numerical","questions","forecasting","processing","experimental","simplicity","uncoupled","processor","attention","techniques","possibility","significant","structure","artificial","statement","challenging","automatic","statements","recognition","accurately","variation","outperforms","successful","characterized","representation","modelling","architectures","classifying","classification","exhibited","convolutional","excellent","interaction","minimizing","experiment","performed","reconstruction","effective","corrupting","introducing","contractive","frobenius","reconstructing","connected","synthetic","inference","combining","alternative","traditional","integrative","clustering","probabilistic","simultaneous","improvement","similarity","information","integrating","vectorial","simultaneously","indicates","conducted","describes","extensively","stochastic","algorithm","efficiently","transforming","correlations","qualitative","statistical","generating","synchronously","sequences","rehabilitation","regression","dimensional","locomotion","predicting","exploiting","predicted","description","correlation","participating","identical","advertising","sublinear","strategies","adversaries","variables","competing","sequentially","knowledge","achievable","logarithmic","adversarial","hindsight","motivated","selection","simulations","procedure","including","uhlenbeck","penalization","restricted","eigenvalue","inequality","asymptotics","financial","continuous","asymptotic","likelihood","penalized","observation","assumption","mandatory","illustrate","consistency","approaches","parameter","preference","alternatives","technique","different","consistent","analysing","conventional","accounting","environment","inclusion","analogies","meaningful","effectiveness","indicators","calculation","explained","translation","demonstrates","memristors","neuromorphic","increasing","connection","plasticity","suggested","interface","consequence","communicating","memristor","connecting","effectively","presenting","operations","probability","automatically","foreground","detection","described","segmentation","difficult","background","generates","represented","multiagent","exponential","naturally","approximate","potential","arguments","formulate","approximation","formulated","theoretical","adequately","discretization","processes","collaborative","particular","formulation","functions","framework","comparison","displayed"],"y":[23,139,455,69,203,1,156,285,45,6,608,870,53,45,27,325,10,594,147,86,70,22,325,376,26,2,17,186,384,45,230,330,148,5,266,193,14,410,62,71,263,77,23,370,49,128,43,497,7,396,23,83,46,83,117,102,249,2,52,2,7,14,83,139,208,108,110,159,2,146,153,19,126,146,697,38,3,115,22,78,90,29,136,797,163,13,27,56,170,97,1,110,2,106,188,5,80,81,44,63,65,10,18,9,6,96,3,110,25,21,344,6,22,87,2,59,148,44,130,265,2,1,57,5,9,1,8,117,18,54,6,61,59,1,67,61,453,122,21,24,250,735,86,8,123,6,126,10,4,54,217,9,25,18,104,60,2,12,105,33,8,26,31,22,2,5,14,116,26,64,171,197,23,367,72,204,162,65,55,80,8,59,53,124,153,21,40,117,34,178,10,13,90,26,263,94,193,543,115,8],"type":"bar"},{"x":["remarkable","therefore","applications","dependent","benchmark","emulation","computing","significantly","pot ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4558,), (4558, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8066666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Poisson</span> <span style=''>Noise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reduction</span> <span style=''>with</span> <span style=''>Higher</span> <span style=''>order</span> <span style=''>Natural</span> <span style=''>Image</span> <span style=''>Prior</span> <span style=''>Model</span> <br/><br/><span style=''>Poisson</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5164835164835164);'>essential</span> <span style=''>issue</span> <span style=''>for</span> <span style=''>various</span> <span style=''>imaging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style=''>night</span> <span style=''>vision</span> <span style=''>medical</span> <span style=''>imaging</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>microscopy</span> <span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>are</span> <span style=''>clearly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dominated</span> <span style=''>by</span> <span style=''>patch</span> <span style=''>based</span> <span style=''>non</span> <span style=''>local</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>to</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>local</span> <span style=''>Poisson</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style=''>model</span> <span style=''>with</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplicity</span> <span style=''>and</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5222672064777327);'>variational</span> <span style=''>modeling</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.5142857142857142);'>integrate</span> <span style=''>the</span> <span style=''>so</span> <span style=''>called</span> <span style=''>Fields</span> <span style=''>of</span> <span style=''>Experts</span> <span style=''>(FoE)</span> <span style=''>image</span> <span style=''>prior</span> <span style=''>that</span> <span style=''>has</span> <span style=''>proven</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Fields</span> <span style=''>(MRF)</span> <span style=''>model</span> <span style=''>for</span> <span style=''>many</span> <span style=''>classic</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>restoration</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>exploit</span> <span style=''>several</span> <span style=''>feasible</span> <span style='background-color:rgba(255, 0, 0, 0.5222672064777327);'>variational</span> <span style=''>variants</span> <span style=''>for</span> <span style=''>this</span> <span style=''>task</span> <span style=''>We</span> <span style=''>start</span> <span style=''>with</span> <span style=''>a</span> <span style=''>direct</span> <span style=''>modeling</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Convergence</span> <span style=''>of</span> <span style=''>SVRG</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>SVRG</span> <span style=''>and</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>are</span> <span style=''>among</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>SVRG</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>linearly</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>is</span> <span style=''>strongly</span> <span style=''>convex</span> <span style=''>However</span> <span style=''>this</span> <span style=''>setup</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restrictive</span> <span style=''>and</span> <span style=''>does</span> <span style=''>not</span> <span style=''>include</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulations</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Lasso</span> <span style=''>group</span> <span style=''>Lasso</span> <span style=''>logistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style=''>some</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrected</span> <span style=''>Lasso</span> <span style=''>and</span> <span style=''>SCAD</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>for</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>M</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>covering</span> <span style=''>examples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mentioned</span> <span style=''>above</span> <span style=''>SVRG</span> <span style=''>solves</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>with</span> <span style=''>em</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>without</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style=''>or</span> <span style=''>even</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>makes</span> <span style=''>use</span> <span style=''>of</span> <span style=''>em</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>strong</span> <span style='background-color:rgba(0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Enhanced</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <br/><br/><span style=''>This</span> <span style=''>letter</span> <span style=''>proposes</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrices</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulating</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.40625);'>regularization</span> <span style=''>We</span> <span style=''>employ</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>penalty</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>non</span> <span style=''>zero</span> <span style=''>singular</span> <span style=''>values</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style=''>than</span> <span style=''>the</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style=''>A</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style=''>for</span> <span style=''>the</span> <span style=''>global</span> <span style=''>optimum</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>(sum</span> <span style=''>of</span> <span style=''>data</span> <span style=''>fidelity</span> <span style=''>and</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>regularizer)</span> <span style=''>is</span> <span style=''>also</span> <span style=''>derived</span> <span style=''>The</span> <span style=''>solution</span> <span style=''>reduces</span> <span style=''>to</span> <span style=''>singular</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.4042553191489362);'>thresholding</span> <span style=''>method</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Effects</span> <span style=''>of</span> <span style=''>Batch</span> <span style=''>and</span> <span style=''>Weight</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Normalization</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>networks</span> <span style=''>(GANs)</span> <span style=''>are</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frameworks</span> <span style=''>that</span> <span style=''>can</span> <span style=''>generate</span> <span style=''>very</span> <span style=''>sharp</span> <span style=''>data</span> <span style=''>even</span> <span style=''>for</span> <span style=''>data</span> <span style=''>such</span> <span style=''>as</span> <span style=''>images</span> <span style=''>with</span> <span style=''>complex</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multimodal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>However</span> <span style=''>GANs</span> <span style=''>are</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style=''>very</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suffering</span> <span style=''>from</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>mode</span> <span style=''>collapse</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disturbing</span> <span style=''>visual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artifacts</span> <span style=''>Batch</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalization</span> <span style=''>(BN)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style=''>address</span> <span style=''>the</span> <span style=''>training</span> <span style=''>Though</span> <span style=''>BN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerates</span> <span style=''>the</span> <span style=''>training</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>beginning</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>BN</span> <span style=''>can</span> <span style=''>be</span> <span style=''>unstable</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>negatively</span> <span style=''>impact</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>trained</span> <span style=''>model</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style=''>BN</span> <span style=''>and</span> <span style=''>numerous</span> <span style=''>other</span> <span style=''>recent</span> <span style=''>schemes</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13237924865831843)
# 	knowledge (0.12307692307692308)
# 	experimental (0.13452593917710196)
# 	segmentation (0.07298747763864043)
# 	processing (0.11627906976744186)
# 	information (0.24937388193202148)
# 	detection (0.13130590339892664)
# 	different (0.2629695885509839)
# 	convolutional (0.14168157423971378)
# 	recognition (0.14669051878354203)
#
# Some Statistics words are:
# 	convergence (0.12418952618453866)
# 	theoretical (0.15261845386533665)
# 	variables (0.13615960099750624)
# 	statistical (0.1596009975062344)
# 	estimation (0.17356608478802993)
# 	inference (0.18403990024937655)
# 	algorithm (0.4024937655860349)
# 	distribution (0.1910224438902743)
# 	dimensional (0.19650872817955112)
# 	regression (0.18453865336658354)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6e51fa7f-2649-4bb1-8726-779ee2d983eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e51fa7f-2649-4bb1-8726-779ee2d983eb")) {                    Plotly.newPlot(                        "6e51fa7f-2649-4bb1-8726-779ee2d983eb",                        [{"x":["remarkable","therefore","applications","dependent","benchmark","emulation","computing","significantly","potentially","reservoir","experiments","performance","nonlinear","implementations","computers","introduce","investigations","demonstrate","generation","numerical","questions","forecasting","processing","experimental","simplicity","uncoupled","processor","attention","techniques","possibility","significant","structure","artificial","statement","challenging","automatic","statements","recognition","accurately","variation","outperforms","successful","characterized","representation","modelling","architectures","classifying","classification","exhibited","convolutional","excellent","interaction","minimizing","experiment","performed","reconstruction","effective","corrupting","introducing","contractive","frobenius","reconstructing","connected","synthetic","inference","combining","alternative","traditional","integrative","clustering","probabilistic","simultaneous","improvement","similarity","information","integrating","vectorial","simultaneously","indicates","conducted","describes","extensively","stochastic","algorithm","efficiently","transforming","correlations","qualitative","statistical","generating","synchronously","sequences","rehabilitation","regression","dimensional","locomotion","predicting","exploiting","predicted","description","correlation","participating","identical","advertising","sublinear","strategies","adversaries","variables","competing","sequentially","knowledge","achievable","logarithmic","adversarial","hindsight","motivated","selection","simulations","procedure","including","uhlenbeck","penalization","restricted","eigenvalue","inequality","asymptotics","financial","continuous","asymptotic","likelihood","penalized","observation","assumption","mandatory","illustrate","consistency","approaches","parameter","preference","alternatives","technique","different","consistent","analysing","conventional","accounting","environment","inclusion","analogies","meaningful","effectiveness","indicators","calculation","explained","translation","demonstrates","memristors","neuromorphic","increasing","connection","plasticity","suggested","interface","consequence","communicating","memristor","connecting","effectively","presenting","operations","probability","automatically","foreground","detection","described","segmentation","difficult","background","generates","represented","multiagent","exponential","naturally","approximate","potential","arguments","formulate","approximation","formulated","theoretical","adequately","discretization","processes","collaborative","particular","formulation","functions","framework","comparison","displayed","measurement","mathematical","sensitive","specifically","literature","understanding","implementation","requirements","mammographic","boundaries","overlapping","important","enhancing","corresponding","mammogram","visualization","challenge","algorithms","operators","locations","representing","objectively","available","application","leaderboard","conclusion","following","interpret","competitions","something","overfitting","precision","participants","complexity","inevitable","introduced","eliminating","redundant","computation","aggression","theoretically","community","grammatical","differences","attracted","generator","addressed","anonymous","proposing","published","generative","carefully","distribution","encountering","phenomenon","prediction","concentrates","predict ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	interpolating
# 	stratified
# 	supermodular
# 	colombian
# 	tabulation
# 	macroeconomic
# 	representer
# 	straggler
# 	stragglers
# 	martingale
# 	psychiatry
# 	metropolis
# 	predetermined
# 	debiasing
# 	diverging
# 	disentangles
# 	confounder
# 	inappropriately
# 	blockmodel
# 	deterioration
# Some words which never appear in Statistics papers:
# 	contractive
# 	memristors
# 	plasticity
# 	memristor
# 	mammographic
# 	mammogram
# 	competent
# 	continually
# 	rejecting
# 	immutable
# 	agreements
# 	paintings
# 	headlines
# 	clickbait
# 	clickbaits
# 	abstractions
# 	existential
# 	decidability
# 	decidable
# 	formalisms

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0761658668635414e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
